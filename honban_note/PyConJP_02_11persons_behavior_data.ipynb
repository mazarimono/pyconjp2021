# %% [markdown]
# <a href="https://colab.research.google.com/github/mazarimono/pyconjp2021/blob/main/PyConJP_02_11persons_behavior_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GIS with Python！！！
# ## Notebook "Personal Behavior Data" part
# - Chomoku LLC: Hideyuki Ogawa
# - My twitter([@ogawahideyuki](https://twitter.com/ogawahideyuki))
# - Company twitter [@hijichomoku](https://twitter.com/hijichomoku)
# - https://chomoku.com/
#
# - Data: GPS tragectiry Linked data project
#   - https://github.com/koujikozaki/GPS2LOD

# %%
# Important library for many geopython libraries
# !apt install gdal-bin python-gdal python3-gdal &> /dev/null
# Install rtree - Geopandas requirment
# !apt install python3-rtree &> /dev/null
# Install Geopandas
# !pip install git+git://github.com/geopandas/geopandas.git &> /dev/null
# Install descartes - Geopandas requirment
# !pip install descartes &> /dev/null
# !pip install plotly -U &> /dev/null

# %%
import time # 時間をコントロール
from typing import List 
from datetime import datetime, date # 日時をコントロール
import requests # requests: https://docs.python-requests.org/en/latest/
import pandas as pd # pandas: 表データを扱う: https://pandas.pydata.org/
import geopandas as gpd # geopandas: 位置データを含む表データを扱う: https://geopandas.org/
import folium # folium: 位置データを可視化する: http://python-visualization.github.io/folium/
from folium import plugins
import shapely.geometry

# %%
# read data: data is every 30 minites positional data
data = gpd.read_file('/content/drive/MyDrive/pyconjp2021/data/gps_data.geojson')
data['dt'] = pd.to_datetime(data['dt'])
data['date'] = data['dt'].map(lambda x: x.date()) # Add date to column
data
# Out:
#                      dt   Latitude  ...                    geometry        date
# 0   2016-10-17 11:00:00  34.665825  ...  POINT (135.21440 34.66582)  2016-10-17
# 1   2016-10-17 12:00:00  34.665089  ...  POINT (135.21423 34.66509)  2016-10-17
# 2   2016-10-17 12:30:00  34.668037  ...  POINT (135.21272 34.66804)  2016-10-17
# 3   2016-10-17 13:30:00  34.665871  ...  POINT (135.21277 34.66587)  2016-10-17
# 4   2016-10-17 14:00:00  34.665062  ...  POINT (135.21156 34.66506)  2016-10-17
# ..                  ...        ...  ...                         ...         ...
# 814 2016-10-22 00:00:00  34.684200  ...  POINT (135.18810 34.68420)  2016-10-22
# 815 2016-10-22 10:30:00  34.687901  ...  POINT (135.19720 34.68790)  2016-10-22
# 816 2016-10-22 11:00:00  34.695118  ...  POINT (135.19495 34.69512)  2016-10-22
# 817 2016-10-22 11:30:00  34.695759  ...  POINT (135.19459 34.69576)  2016-10-22
# 818 2016-10-22 12:30:00  34.698639  ...  POINT (135.19426 34.69864)  2016-10-22
#
# ...

# %% [markdown]
# ## visualize data
#
# I will check if everyone took the event seriously.(joking)
#
# - median point
#     - looking for hall
#     - http://iswc2016.semanticweb.org/pages/attending/venue.html
# - heat map
# - point map
# - speed (same timestamp)

# %%
# centroid does not work
# use float data
lat_med = data["Latitude"].median()
lon_med = data["Longitude"].median()

map = folium.Map([lat_med, lon_med], zoom_start=15)
folium.Marker([lat_med, lon_med]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# data watch with heatmap
matrix_data = data[['Latitude', 'Longitude']].values

map = folium.Map([center.y, center.x])
map.add_child(plugins.HeatMap(matrix_data))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# - someone go to Miki!!
# - some one go to Osaka!!

# %%
data
# Out:
#                      dt   Latitude  ...                    geometry        date
# 0   2016-10-17 11:00:00  34.665825  ...  POINT (135.21440 34.66582)  2016-10-17
# 1   2016-10-17 12:00:00  34.665089  ...  POINT (135.21423 34.66509)  2016-10-17
# 2   2016-10-17 12:30:00  34.668037  ...  POINT (135.21272 34.66804)  2016-10-17
# 3   2016-10-17 13:30:00  34.665871  ...  POINT (135.21277 34.66587)  2016-10-17
# 4   2016-10-17 14:00:00  34.665062  ...  POINT (135.21156 34.66506)  2016-10-17
# ..                  ...        ...  ...                         ...         ...
# 814 2016-10-22 00:00:00  34.684200  ...  POINT (135.18810 34.68420)  2016-10-22
# 815 2016-10-22 10:30:00  34.687901  ...  POINT (135.19720 34.68790)  2016-10-22
# 816 2016-10-22 11:00:00  34.695118  ...  POINT (135.19495 34.69512)  2016-10-22
# 817 2016-10-22 11:30:00  34.695759  ...  POINT (135.19459 34.69576)  2016-10-22
# 818 2016-10-22 12:30:00  34.698639  ...  POINT (135.19426 34.69864)  2016-10-22
#
# ...

# %%
# watch each person's data with timestamp

ps_color = {'number1': 'blue',
            'number2': 'green',
            'number3': 'white',
            'number4': 'gray',
            'number5': 'black',
            'number6': 'red',
            'number7': 'orange',
            'number8': 'pink',
            'number9': 'purple',
            'number10': 'lime',
            'number11': 'yellow'
            }
center = shapely.geometry.MultiPoint(data1['geometry'].values).centroid

map = folium.Map(location=[center.y, center.x])
for i in data.index:
    num = data.loc[i, 'number']
    selected_color=ps_color[num]
    pos_i = data.loc[i, 'geometry']
    time_i = data.loc[i, 'dt']
    folium.Marker([pos_i.y, pos_i.x], popup=f'{num}: {time_i}', icon=folium.Icon(color=selected_color)).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# watch activity same datetime

d_time = datetime(2016, 10, 20, 13, 0)

dff = data[data['dt'] == d_time]
matrix_data = dff[['Latitude', 'Longitude']].values

map = folium.Map([center.y, center.x], zoom_start=14)
map.add_child(plugins.HeatMap(matrix_data))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
# watch speed same datetime

d_time = datetime(2016, 10, 20, 13, 0)

dff = data[data['dt'] == d_time]
center = shapely.geometry.MultiPoint(data['geometry'].values).centroid
map = folium.Map([center.y, center.x], zoom_start=14)

for i in dff.index:
    pos_i = dff.loc[i, 'geometry']
    speed_i = dff.loc[i, 'Speed']/100
    popup = f"{dff.loc[i, 'number']}: {speed_i}"
    folium.Circle([pos_i.y, pos_i.x], radius=speed_i, popup=popup).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
